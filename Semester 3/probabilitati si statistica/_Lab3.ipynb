# %%
from random import choices, sample
from math import comb, perm

#1. a.
lista = ['r', 'r', 'r', 'r', 'r', 'a' ,'a','a','v','v']
cont_A = 0
cont_A_B =0
for i in range(1000):
  lista_extrasa = sample(lista, 3)
  if lista_extrasa[0] == 'r' or lista_extrasa[1] == 'r' or lista_extrasa[2] == 'r':
    cont_A +=1
    if lista_extrasa[0] == 'r' and lista_extrasa[1] == 'r' and lista_extrasa[2] == 'r':
      cont_A_B += 1
cont_A_B/cont_A


#b.
(comb(5,3)/comb(10,3))/(1-comb(5,3)/comb(10,3))
# Out:
# 0.09090909090909091

# %%
#2.
from random import randrange
from matplotlib.pyplot import bar, hist, grid, show, legend

data = [randrange(1,7) for _ in range(1000)]
bin_edges = [k+0.5 for k in range(7)]
hist(data, bin_edges, density = True, rwidth = 0.9, color = 'green', edgecolor = 'black', alpha = 0.5, label = 'frecvente relative')

distribution = dict([(k, 1/6) for k in range (1,7)])
bar(distribution.keys(), distribution.values(),  width = 0.85, color = 'red', edgecolor = 'black', alpha= 0.6, label = 'probabilitati')

legend(loc = 'lower left')
grid()
show()

# %%
from scipy.stats import binom

#3. CU RETURNARE
# suma numerelor (avand in vedere ca avem 1 si 0) e acelasi lucru cu sa spunem cate de 1 s au returnat
#binom.rvs(n=100, p=1/3, size = 10)
#a.
data = binom.rvs(n=5,p=6/10, size=1000)
#b.
bin_edges = [k+0.5 for k in range(-1,6)]
hist(data, bin_edges, density = True, rwidth = 0.9, color = 'green', edgecolor = 'black', alpha = 0.5, label = 'frecvente relative')

binom.pmf
distribution = dict([(k, binom.pmf(k,n=5,p=6/10)) for k in range(6)])
bar(distribution.keys(), distribution.values(),  width = 0.85, color = 'red', edgecolor = 'black', alpha= 0.6, label = 'probabilitati')

legend(loc = 'lower left')
grid()
show()

#c.
binom.cdf(k=5, n=5,p=6/10) - binom.cdf(k=2, n=5,p=6/10)
#varinata 2
#sum([2<x<=5 for x in data])/len(data)
# Out:
# 0.68256
